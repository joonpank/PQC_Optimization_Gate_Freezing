# %%
import pandas as pd
from scipy.interpolate import splrep, BSpline
from scipy.interpolate import UnivariateSpline
from scipy.interpolate import interp1d

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os

# %%
trials = 50
layers = 3
qubits = 5
iters = 30

# choose "param" or "matrix" for distance metric. 
# Matrix distance has only results for Ansatz A
dist_metric = "param" # "matrix"

# Choose ansatz: A, B, C or D
ansatz = "A"

dvals = [0.01,0.005,0.001]

fig, axes = plt.subplots(1, len(dvals))

fig.set_figheight(6)
fig.set_figwidth(15)

for d, ax in zip(dvals, axes.flatten()):
    if dist_metric == "param":
        df = pd.read_excel(f"data/1DHeisenberg_{qubits}Q_FQS_NoFreezeCounts_GCdist_d{d}_GateIters_{iters}cycles_{layers}layers_{trials}trials_{ansatz}.xlsx")
    elif dist_metric == "matrix":
        df = pd.read_excel(f"data/1DHeisenberg_{qubits}Q_FQS_NoFreezeCounts_MatrixDist_d{d}_GateIters_{iters}cycles_{layers}layers_{trials}trials_{ansatz}.xlsx")
    df["mean"] = df.mean(axis=1) 
    means = np.array(df["mean"]) 

    c = means.reshape(layers, qubits).T
    #print(c)
    im = ax.imshow(c, cmap='jet', interpolation='nearest')
    clb = plt.colorbar(im, ax=ax, shrink=0.99)
    clb.ax.tick_params(labelsize=30) 
    ax.set_title(f"T = {d}", fontsize=34, y=1.03)
    
    ax.set_xticks(range(layers))
    ax.set_yticks(range(qubits))

    ax.set_xlabel("Layer index", fontsize=30)
    ax.tick_params(labelsize=30)

axes[0].set_ylabel("Qubit index", fontsize=34)

fig.tight_layout()

# %%
trials = 50
qubits = 5

show_std = True
iters = 25

layers = [5,7,9]
d = 0.005

fig = plt.figure(figsize=(12, 10))
gs = gridspec.GridSpec(2, 2, height_ratios=[1, 1.3])  # bottom row taller

ax1 = fig.add_subplot(gs[0, 0])  # top-left
ax2 = fig.add_subplot(gs[0, 1])  # top-right
ax3 = fig.add_subplot(gs[1, :])  # bottom row spans both columns

axes = np.array([ax1, ax2, ax3])
i = 0
for layer, ax in zip(layers, axes.flatten()):
    df = pd.read_excel(f"data/1DHeisenberg_{qubits}Q_FQS_NoFreezeCounts_GCdist_d{d}_GateIters_{iters}cycles_{layer}layers_{trials}trials_A.xlsx")
    df["mean"] = df.mean(axis=1) 
    means = np.array(df["mean"]) 

    c = means.reshape(layer, qubits).T
    #print(c)
    im = ax.imshow(c, cmap='jet', interpolation='nearest')
    clb = plt.colorbar(im, ax=ax, shrink=1, pad = 0.05)
    clb.ax.tick_params(labelsize=30) 
    ax.set_title(f"{layer} layers", fontsize=34, y=1.03)
    ax.set_xticks(range(layer))
    ax.set_yticks(range(qubits))

    ax.tick_params(labelsize=28)
    if i==0 or i==2:
        ax.set_ylabel("Qubit index", fontsize=30, labelpad =20)

    ax.set_xlabel("Layer index", fontsize=30, labelpad = 10)
    i+=1

fig.tight_layout()
